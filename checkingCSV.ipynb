# %%
import pandas as pd
from prediction.classify_predict import compute_implied_probability

# %%
classified_df = pd.read_csv('prediction/output/classified_predictions.csv')
classified_df.head()
# Out:
#                                                  uri  \
# 0  at://did:plc:uja4msdr44t62szbfe5wzdu4/app.bsky...
# 1  at://did:plc:zy6nkkusnwgio57qkp7fhwuh/app.bsky...
# 2  at://did:plc:buj3fjj6dar54jcdvvsp3m5n/app.bsky...
# 3  at://did:plc:rmrgs7t75mvedc2zbnvnv6og/app.bsky...
# 4  at://did:plc:6lpk72rqnczhh3f2ykm2nytl/app.bsky...
#
#                                                  cid  \
# 0  bafyreig6dhq6jv6bv3ujpk7zt5fn6jxvof5o66tqo7mu2...
# 1  bafyreif3lhtl3qpbgdbi3mnfezebcgnif5w2k4ic4fi2w...
# 2  bafyreialjbalip74yzkfmtupow42k32r6mazzyvkm7fun...
# 3  bafyreibzqfclchf4jliol3zwso6cfvf6stop4mlicsil7...
# 4  bafyreidhyid765zheq76uh5vww54aaze26akkoxr7j76x...
#
#                author_handle                        author_did  \
# 0  joelmarques84.bsky.social  did:plc:uja4msdr44t62szbfe5wzdu4
# 1  bearlyfantasy.bsky.social  did:plc:zy6nkkusnwgio57qkp7fhwuh
# 2     sonnycohen.bsky.social  did:plc:buj3fjj6dar54jcdvvsp3m5n
# 3   poppy1234567.bsky.social  did:plc:rmrgs7t75mvedc2zbnvnv6og
# ...

# %%
import os 
os.environ["DATABASE_URL"] = "postgresql://daaatabase_user:c4aJ0oxLn0H1WbtvnaIIfpFtwojt4lps@dpg-d984p8mrnols73emqqbg-a.oregon-postgres.render.com/daaatabase"
os.environ["BLUESKY_USERNAME"] = "ccramir.bsky.social"
os.environ["BLUESKY_PASSWORD"] = "bdmn-w6bp-oulf-3sg5"

# %%
# !python api/kalshi_ingest.py --url "https://kalshi.com/markets/kxpresparty/party-winning-presidency/kxpresparty-2028"
# Out:
# Fetching contract: series=KXPRESPARTY  event=KXPRESPARTY-2028
#
# [Bluesky] KXPRESPARTY_2028  window: 2026-07-09T22:12:55.916480Z ----> 2026-07-10T10:12:55.916480Z
# [Bluesky] 8500 unique posts -> BLUESKY_POSTS_KXPRESPARTY_2028.csv

# %%
import pandas as pd

df = pd.read_csv("BLUESKY_POSTS_KXPRESPARTY_2028.csv")
df.head(200).to_csv("BLUESKY_POSTS_KXPRESPARTY_2028_SAMPLE.csv", index=False)
print(f"Trimmed to {len(df.head(200))} rows")
# Out:
# Trimmed to 200 rows

# %%
# !python -u -m prediction.classify_predict --input BLUESKY_POSTS_KXPRESPARTY_2028_SAMPLE.csv
# Out:
# -- KXPRESPARTY_2028_SAMPLE (BLUESKY_POSTS_KXPRESPARTY_2028_SAMPLE.csv)
# Classifying 200 posts with 8 workers...
#   [KXPRESPARTY_2028_SAMPLE] None | High | The antisemitism (& also, by using the term “Establishment Dems” they are attack
#   [KXPRESPARTY_2028_SAMPLE] None | High | Also, give me more reasons and/or excuses on why I should be forced and threaten
#   [KXPRESPARTY_2028_SAMPLE] None | High | because someone in hospital unable to talk to media TOTALLY talks to Republican
#   [KXPRESPARTY_2028_SAMPLE] None | High | Also, give me more reasons and/or excuses on why I should be forced and threaten
#   [KXPRESPARTY_2028_SAMPLE] None | High | This is music to Trump and MAGA -EARS!! This woman is telling voters in Maine no
#   [KXPRESPARTY_2028_SAMPLE] None | High | www.threads.com/@kaceerallen... Vote Blue in November and stop this insanity!
#   [KXPRESPARTY_2028_SAMPLE] None | High | I lol’d  Alt text: The fact that you can be brain dead and still be a Republican
# ...

# %%
print(classified_df.shape)
print("Democrat's Posts: ", (classified_df['predicted_party'] == 'Democrat').sum())
print("Republican's Posts: ", (classified_df['predicted_party'] == 'Republican').sum())
print("Non-predictive Posts: ", (classified_df['predicted_party'].isnull()).sum())
# Out:
# (6038, 19)
# Democrat's Posts:  14
# Republican's Posts:  13
# Non-predictive Posts:  6011

# %%
compute_implied_probability(classified_df)
# Out:
# --- Bluesky Implied Probability ---
#   Democrat:    53.8%  (7 posts)
#   Republican:  46.2%  (6 posts)
#   Third Party: 0.0%  (0 posts)
#   Total predictive posts: 13
# {'Democrat': np.float64(0.5385),
#  'Republican': np.float64(0.4615),
#  'Third Party': np.float64(0.0)}

# %%
df = pd.read_csv('BLUESKY_POSTS_KXPRESPARTY_2028.csv')
df.head()
# Out:
#                                                  uri  \
# 0  at://did:plc:rudwzj5uwhvocjdhltfuewmn/app.bsky...
# 1  at://did:plc:xtrlfckue4nevvszdzlqbmlz/app.bsky...
# 2  at://did:plc:odu6ujihvuflnsw5zy4hog6h/app.bsky...
# 3  at://did:plc:nj7iog6v4yov2e7tctmwq6n3/app.bsky...
# 4  at://did:plc:mejqjsugpcokug4wugy2wzk3/app.bsky...
#
#                                                  cid  \
# 0  bafyreif22oinsbq5ntxniinoic2dlow7rhyz7htehx65e...
# 1  bafyreibpvmwqjg7x57jdtxcoehzi3ry567fka45yyzksg...
# 2  bafyreiepkftz5eb4bxwkhup5v33e7ed7eppljdhwe5f2w...
# 3  bafyreih633p2heamhodlidjlyj3js2oynr45dnoqxilqj...
# 4  bafyreibtdgdtuyk4q4iznrtgqy5vtwogcwnqiqw2jt3ox...
#
#                  author_handle                        author_did  \
# 0          colin25.bsky.social  did:plc:rudwzj5uwhvocjdhltfuewmn
# 1        jomarie05.bsky.social  did:plc:xtrlfckue4nevvszdzlqbmlz
# 2         deltaowl.bsky.social  did:plc:odu6ujihvuflnsw5zy4hog6h
# ...

# %%
compute_implied_probability(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/seo-project2/seotechdev-project2/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
